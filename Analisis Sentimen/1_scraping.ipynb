# %%
# !pip install google-play-scraper pandas

import pandas as pd
from google_play_scraper import reviews, Sort

print("Memulai proses scraping 20.000 ulasan Tokopedia (agar sisa >10.000)...")
result, continuation_token = reviews(
    'com.tokopedia.tkpd',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=20000
)

df = pd.DataFrame(result)[['content']]
df.columns = ['ulasan']

# Bersihkan data kosong & duplikat
df.dropna(inplace=True)
df.drop_duplicates(subset=['ulasan'], inplace=True)

df.to_csv('dataset_tokopedia_mentah.csv', index=False)
print(f"✅ Scraping Selesai! Total data unik: {len(df)} baris.")
print("Silakan download 'dataset_tokopedia_mentah.csv'")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.1 MB/s eta 0:00:00
# ...
# Memulai proses scraping 20.000 ulasan Tokopedia (agar sisa >10.000)...
# ✅ Scraping Selesai! Total data unik: 16122 baris.
# Silakan download 'dataset_tokopedia_mentah.csv'
